# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import rasterio 

# Path del raster
raster_path = r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\DTM+BDTRE_QGIS\DTM\DTM5\DTM5 Cervo Valley.tif"

# Path dei file shapefile
shp_paths = [
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Cervo Valley Slopes\Slopes_0-15%_Polygons_DTM25.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Cervo Valley Slopes\Slopes_15-30%_Polygons_DTM25.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Cervo Valley Slopes\Slopes_30-35%_Polygons_DTM25.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Cervo Valley Slopes\Slopes_35-70%_Polygons_DTM25.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Cervo Valley Slopes\Slopes_70-100%_Polygons_DTM25.shp"
]

# Colori per i file shapefile
colors = ['green', 'blue', 'red', 'yellow', 'black']

# Leggi il raster
raster = rasterio.open(raster_path)

# Crea la figura
plt.figure(figsize=(12, 10))

# Leggi e plotta i file shapefile sovrapposti
for i, shp_path in enumerate(shp_paths):
    gdf = gpd.read_file(shp_path)
    gdf.plot(ax=plt.gca(), color=colors[i])

# Crea una legenda per i colori
legend_elements = [
    Patch(facecolor='green', edgecolor='green', label='Slow drips risk (0-15%)'),
    Patch(facecolor='blue', edgecolor='blue', label='Quick drips risk (15-30%)'),
    Patch(facecolor='red', edgecolor='red', label='Rotational/translational slip risk (30-35%)'),
    Patch(facecolor='yellow', edgecolor='yellow', label='Complex terrain movement risk (35-70%)'),
    Patch(facecolor='black', edgecolor='black', label='Blockage risk (70-100%)')
]

# Aggiungi la legenda al grafico
plt.legend(handles=legend_elements, title="Slopes %", loc='upper left', fontsize=8, bbox_to_anchor=(1, 1))

# Assegna etichette agli assi
plt.xlabel('Longitude', fontweight='bold')
plt.ylabel('Latitude', fontweight='bold')
plt.title('CERVO VALLEY SLOPES COLOR MAP',fontweight='bold')

# Mostra il grafico
plt.show()

# %%
#COLLE MOLOGNA PLOT
import geopandas as gpd
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Path del raster
raster_path = r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Colle Mologna\Crop Colle Mologna.tif"
# Path dei file shapefile
shp_paths = [
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Colle Mologna\Colle Mologna_Slopes_0-15%.cpg\Colle Mologna_Slopes_0-15%_Polygons.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Colle Mologna\Colle Mologna_Slopes_0-15%.cpg\Colle Mologna Slopes_15-30%_Polygons.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Colle Mologna\Colle Mologna_Slopes_0-15%.cpg\Colle Mologna Slopes_30-35%_Polygons.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Colle Mologna\Colle Mologna_Slopes_0-15%.cpg\Colle Mologna Slopes_35-70%_Polygons.shp",
    r"C:\Users\noemi\Dropbox (Politecnico Di Torino Studenti)\Magistrale\II anno_UGent\Thesis\QGIS_PYTHON\Python\Colle Mologna\Colle Mologna_Slopes_0-15%.cpg\Colle Mologna Slopes_70-100%_Polygons.shp"
]

# Colori per i file shapefile
colors = ['green', 'blue', 'red', 'yellow', 'black']

# Coordinate del marker
marker_x, marker_y = 416568, 5062647

# Leggi il raster
raster = rasterio.open(raster_path)

# Crea la figura
plt.figure(figsize=(12, 10))

# Leggi e plotta i file shapefile sovrapposti
for i, shp_path in enumerate(shp_paths):
    gdf = gpd.read_file(shp_path)
    gdf.plot(ax=plt.gca(), color=colors[i])

# Aggiungi il marker alle coordinate specificate
plt.scatter(marker_x, marker_y, color='pink', marker='o', s=150)

# Crea una legenda per i colori
legend_elements = [
    Patch(facecolor='green', edgecolor='green', label='Slow drips risk (0-15%)'),
    Patch(facecolor='blue', edgecolor='blue', label='Quick drips risk (15-30%)'),
    Patch(facecolor='red', edgecolor='red', label='Rotational/translational slip risk (30-35%)'),
    Patch(facecolor='yellow', edgecolor='yellow', label='Complex terrain movement risk (35-70%)'),
    Patch(facecolor='black', edgecolor='black', label='Blockage risk (70-100%)'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='pink', markersize=10, label='Mologna Hill')
]

# Aggiungi la legenda al grafico
plt.legend(handles=legend_elements, title="Slopes %", loc='upper left', fontsize=8, bbox_to_anchor=(1, 1))

# Assegna etichette agli assi
plt.xlabel('Longitude', fontweight='bold')
plt.ylabel('Latitude', fontweight='bold')
plt.title('MOLOGNA HILL SLOPES COLOR MAP',fontweight='bold')

# Mostra il grafico
plt.show()
